# %%
'''Part 1: Connecting to CityBikes API'''
# Out:
# <function get_all_bike_stations at 0x146332340>

# %%
import requests

def get_all_bike_stations(city):
    url = f"https://api.citybikes.com/v2/networks/{city}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        bike_stations = data['network']['stations']
        return bike_stations
    else:
        # Handle error case
        print(f"Error: {response.status_code}")
        return None
print(get_all_bike_stations)
# Out:
# <function get_all_bike_stations at 0x108bab2e0>

# %%
#Choose a city covered by the CityBikes API and retrieve all available bike stations in that city.


import requests
import logging

def get_bike_stations(city):
    url = f"http://api.citybik.es/v2/networks/{city}?fields=id,name,href"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises an exception for non-200 status codes
        data = response.json()
        bike_stations = data.get('network', {}).get('stations', [])
        return bike_stations
    except requests.exceptions.RequestException as e:
        logging.error(f"Error occurred during API request: {e}")
        return None
    
toronto_bike_stations = get_bike_stations("toronto")
print(toronto_bike_stations )
# Out:
# [{'empty_slots': 7, 'extra': {'address': 'Queen St E / Woodward Ave', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938367, 'normal_bikes': 12, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 19, 'uid': '7303'}, 'free_bikes': 12, 'id': 'fb337bbed72e2be090071e199899b2be', 'latitude': 43.665269, 'longitude': -79.319796, 'name': 'Queen St E / Woodward Ave', 'timestamp': '2023-11-25T18:54:54.714000Z'}, {'empty_slots': 14, 'extra': {'address': 'Primrose Ave / Davenport Rd', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938330, 'normal_bikes': 0, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 15, 'uid': '7301'}, 'free_bikes': 0, 'id': '4ff88d5880e71aa40d34cfe5d09b0ca7', 'latitude': 43.67142, 'longitude': -79.445947, 'name': 'Primrose Ave / Davenport Rd', 'timestamp': '2023-11-25T18:54:54.721000Z'}, {'empty_slots': 12, 'extra': {'address': 'Queen St. E / Rhodes Ave.', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938373, 'normal_bikes': 11, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 23, 'uid': '7309'}, 'free_bikes': 11, 'id': 'a09c67c0b419654d907c9134b108e328', 'latitude': 43.666224, 'longitude': -79.317693, 'name': 'Queen St E / Rhodes Ave', 'timestamp': '2023-11-25T18:54:54.731000Z'}, {'empty_slots': 6, 'extra': {'address': 'Bond St / Queen St E', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938345, 'normal_bikes': 29, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 37, 'uid': '7045'}, 'free_bikes': 29, 'id': 'd6a9daee68070a8b106cfb598d81308c', 'latitude': 43.653236, 'longitude': -79.376716, 'name': 'Bond St / Queen St E', 'timestamp': '2023-11-25T18:54:54.770000Z'}, {'empty_slots': 22, 'extra': {'address': 'Church St / Alexander St', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938434, 'normal_bikes': 3, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 27, 'uid': '7044'}, 'free_bikes': 3, 'id': '8f8af40d9388c8a3962559e8681d3db7', 'latitude': 43.663722, 'longitude': -79.380288, 'name': 'Church St / Alexander St', 'timestamp': '2023-11-25T18:54:54.773000Z'}, {'empty_slots': 12, 'extra': {'address': 'University Ave / Gerrard St W', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938339, 'normal_bikes': 12, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 25, 'uid': '7047'}, 'free_bikes': 12, 'id': '5a441560e262305d1934fb3ada5a9517', 'latitude': 43.657763, 'longitude': -79.389165, 'name': 'University Ave / Gerrard St W (East Side)', 'timestamp': '2023-11-25T18:54:54.778000Z'}, {'empty_slots': 2, 'extra': {'address': 'Edward St / Yonge St', 'altitude': None, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938372, 'normal_bikes': 20, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 23, 'uid': '7041'}, 'free_bikes': 20, 'id': '18ea490ab3ca4d10e2927308416edbef', 'latitude': 43.656729, 'longitude': -79.382736, 'name': 'Edward St / Yonge St', 'timestamp': '2023-11-25T18:54:54.782000Z'}, {'empty_slots': 15, 'extra': {'address': 'Euclid Ave / Bloor St W', 'altitude': 0.0, 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1700938266, 'normal_bikes': 3, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'rental_uris': {}, 'renting': 1, 'returning': 1, 'slots': 19, 'uid': '7040'}, 'free_bikes': 3, 'id': 'b78509486074743 ...

# %%
# For each bike station, use the API to call the latitude, longitude and number of bikes.

import requests
import logging

def get_bike_stations(city):
    url = f"http://api.citybik.es/v2/networks/{city}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises an exception for non-200 status codes
        data = response.json()
        bike_stations = data.get('network', {}).get('stations', [])
        for station in bike_stations:
            print(f"Station Name: {station.get('name')}")
            print(f"Latitude: {station.get('latitude')}")
            print(f"Longitude: {station.get('longitude')}") 
            print(f"Number of Bikes: {station.get('free_bikes')}") # number of available bikes
            print("-----------------------------") # to clarify the next bike station 
    except requests.exceptions.RequestException as e:
        logging.error(f"Error occurred during API request: {e}")

toronto_bike_stations = get_bike_stations("toronto")
# Out:
# Station Name: Queen St E / Woodward Ave
# Latitude: 43.665269
# Longitude: -79.319796
# Number of Bikes: 12
# -----------------------------
# Station Name: Primrose Ave / Davenport Rd
# Latitude: 43.67142
# Longitude: -79.445947
# Number of Bikes: 0
# -----------------------------
# Station Name: Queen St E / Rhodes Ave
# Latitude: 43.666224
# Longitude: -79.317693
# Number of Bikes: 11
# -----------------------------
# Station Name: Bond St / Queen St E
# Latitude: 43.653236
# Longitude: -79.376716
# Number of Bikes: 29
# -----------------------------
# Station Name: Church St / Alexander St
# Latitude: 43.663722
# Longitude: -79.380288
# Number of Bikes: 3
# -----------------------------
# Station Name: University Ave / Gerrard St W (East Side)
# Latitude: 43.657763
# Longitude: -79.389165
# Number of Bikes: 12
# -----------------------------
# Station Name: Edward St / Yonge St
# Latitude: 43.656729
# Longitude: -79.382736
# Number of Bikes: 20
# -----------------------------
# Station Name: Euclid Ave / Bloor St W
# Latitude: 43.664467
# Longitude: -79.414783
# Number of Bikes: 3
# -----------------------------
# Station Name: Yonge St / Aylmer Ave
# Latitude: 43.675492
# Longitude: -79.388858
# Number of Bikes: 3
# -----------------------------
# Station Name: Davenport Rd / Avenue Rd
# Latitude: 43.674991
# Longitude: -79.396273
# Number of Bikes: 1
# -----------------------------
# Station Name: Yonge St / Yorkville Ave
# Latitude: 43.671944
# Longitude: -79.387778
# Number of Bikes: 8
# -----------------------------
# Station Name: Dundas St E / Broadview Ave
# Latitude: 43.662365
# Longitude: -79.351104
# Number of Bikes: 3
# -----------------------------
# Station Name: Front St W / Yonge St (Hockey Hall of Fame)
# Latitude: 43.646144
# Longitude: -79.377962
# Number of Bikes: 45
# -----------------------------
# Station Name: Gerrard St E / River St
# Latitude: 43.663993
# Longitude: -79.358534
# Number of Bikes: 8
# -----------------------------
# Station Name: Jarvis St / Dundas St E
# Latitude: 43.657266
# Longitude: -79.374756
# Number of Bikes: 0
# -----------------------------
# Station Name: Logan Av / Gerrard St E
# Latitude: 43.6672144
# Longitude: -79.3452697
# Number of Bikes: 5
# -----------------------------
# Station Name: Regal Rd / Dufferin St
# Latitude: 43.673939
# Longitude: -79.441159
# Number of Bikes: 2
# -----------------------------
# Station Name: Morse St / Eastern Ave
# Latitude: 43.657991
# Longitude: -79.340075
# Number of Bikes: 6
# -----------------------------
# Station Name: Alton Ave / Dundas St E (Greenwood Park)
# Latitude: 43.66745
# Longitude: -79.329408
# Number of Bikes: 20
# -----------------------------
# Station Name: Blake St / Boultbee Ave
# Latitude: 43.672453
# Longitude: -79.338259
# Number of Bikes: 5
# -----------------------------
# Station Name: Eastern Ave / Winnifred Ave
# Latitude: 43.6592088
# Longitude: -79.3348396
# Number of Bikes: 10
# -----------------------------
# Station Name: Gamble Ave / Broadview Ave
# Latitude: 43.689211
# Longitude: -79.35438
# Number of Bikes: 2
# -----------------------------
# Station Name: 111 Bond St (North of Dundas St E)  - SMART
# Latitude: 43.656927
# Longitude: -79.378497
# Number of Bikes: 16
# -----------------------------
# Station Name: Dundas St E / Pembroke St - SMART
# Latitude: 43.658295
# Longitude: -79.372346
# Number of Bikes: 6
# -----------------------------
# Station Name: Victoria Park Subway Station - SMART
# Latitude: 43.6940155
# Longitude: -79.2889842
# Number of Bikes: 1
# -----------------------------
# Station Name: Wychwood Ave / Benson Ave - SMART
# Latitude: 43.6809164
# Longitude: -79.4229684
# Number of Bikes: 5
# -----------------------------
# Station Name: Lawton Blvd / Yonge St
# Latitude: 43.6910667
# Longitude: -79.39535
# Number of Bikes: 11
# -----------------------------
# Station Name: Yonge St / Davisville Ave
# Latitude: 43.6975969
# Longitude: -79.39654
# Number of Bikes: 2
# -----------------------------
# Station Name: Fort York  Blvd / Capreol Ct
# Latitude: 43.639832
# Longitude: -79.395954
# Number of Bikes: 16
# -----------------------------
# Station Name: St. George St / Bloor St W
# Latitude: 43.667333
# Longitude: -79.399429
# Number of Bikes: 8
# -----------------------------
# Station Name: King St W / York St
# Latitude: 43.6480008
# Longitude: -79.383177
# Number of Bikes: 19
# -----------------------------
# Station Name: Rosehill Ave / Avoca Ave - SMART
# Latitude: 43.687999
# Longitude: -79.38906
# Number of Bikes: 1
# -----------------------------
# Station Name: Bloor St W / Dundas St W
# Latitude: 43.6563889
# Longitude: -79.45166666666667
# Number of Bikes: 3
# -----------------------------
# Station Name: Bathurst St / Fort York Blvd
# Latitude: 43.639179
# Longitude: -79.399595
# Number of Bikes: 8
# -----------------------------
# Station Name: Spadina Ave / Willcocks St
# Latitude: 43.6616667
# Longitude: -79.40138888888889
# Number of Bikes: 1
# -----------------------------
# Station Name: Cariboo Ave / Railpath Trail
# Latitude: 43.66666667
# Longitude: -79.45833333333334
# Number of Bikes: 16
# -----------------------------
# Station Name: Dundas St W / Edna Ave
# Latitude: 43.657192
# Longitude: -79.452559
# Number of Bikes: 0
# -----------------------------
# Station Name: College St / Major St
# Latitude: 43.6576
# Longitude: -79.4032
# Number of Bikes: 1
# -----------------------------
# Station Name: McGill St / Church St
# Latitude: 43.660694
# Longitude: -79.379052
# Number of Bikes: 3
# -----------------------------
# Station Name: Queens Quay W / Dan Leckie Way
# Latitude: 43.636533
# Longitude: -79.395854
# Number of Bikes: 27
# -----------------------------
# Station Name: College Park South
# Latitude: 43.659777
# Longitude: -79.382767
# Number of Bikes: 7
# -----------------------------
# Station Name: 25 York St – Union Station South
# Latitude: 43.643667
# Longitude: -79.380414
# Number of Bikes: 10
# -----------------------------
# Station Name: 161 Bleecker St (South of Wellesley)
# Latitude: 43.666233
# Longitude: -79.373327
# Number of Bikes: 2
# -----------------------------
# Station Name: Spadina Ave / Fort York Blvd
# Latitude: 43.640114
# Longitude: -79.393249
# Number of Bikes: 12
# -----------------------------
# Station Name: Augusta Ave / Denison Sq
# Latitude: 43.653766
# Longitude: -79.4016759
# Number of Bikes: 2
# -----------------------------
# Station Name: Lansdowne Ave / Whytock Ave
# Latitude: 43.6538888888889
# Longitude: -79.4413888888889
# Number of Bikes: 0
# -----------------------------
# Station Name: Sterling Rd / Dundas St W
# Latitude: 43.6508333333333
# Longitude: -79.4430555555556
# Number of Bikes: 3
# -----------------------------
# Station Name: St Clarens Ave / College St
# Latitude: 43.651238
# Longitude: -79.43868
# Number of Bikes: 0
# -----------------------------
# Station Name: Ossington Ave / College St
# Latitude: 43.6544915
# Longitude: -79.422634
# Number of Bikes: 0
# -----------------------------
# Station Name: High Park Subway Station
# Latitude: 43.6543604
# Longitude: -79.4655296
# Number of Bikes: 9
# -----------------------------
# Station Name: Lake Shore Blvd W / Ellis Ave
# Latitude: 43.635932
# Longitude: -79.465083
# Number of Bikes: 17
# -----------------------------
# Station Name: Parkside Dr / Bloor St W - SMART
# Latitude: 43.654501
# Longitude: -79.460053
# Number of Bikes: 3
# -----------------------------
# Station Name: Lake Shore Blvd W / Windermere Ave
# Latitude: 43.634896
# Longitude: -79.467763
# Number of Bikes: 15
# -----------------------------
# Station Name: Martin Goodman Trail (Marilyn Bell Park)
# Latitude: 43.6314
# Longitude: -79.4304
# Number of Bikes: 16
# -----------------------------
# Station Name: Lake Shore Blvd W / The Boulevard Club
# Latitude: 43.636731
# Longitude: -79.444966
# Number of Bikes: 17
# -----------------------------
# Station Name: Dundas St W / Roncesvalles Ave Green P -SMART
# Latitude: 43.6534268
# Longitude: -79.4512787
# Number of Bikes: 1
# -----------------------------
# Station Name: Erskine Ave / Yonge St SMART
# Latitude: 43.7112153
# Longitude: -79.39894
# Number of Bikes: 2
# -----------------------------
# Station Name: D'Arcy St / McCaul St - SMART
# Latitude: 43.655227
# Longitude: -79.39201
# Number of Bikes: 3
# -----------------------------
# Station Name: Mortimer Ave / Carlaw Ave SMART
# Latitude: 43.685167
# Longitude: -79.34962
# Number of Bikes: 2
# -----------------------------
# Station Name: Cumberland St / Bay St SMART
# Latitude: 43.6704537
# Longitude: -79.39014
# Number of Bikes: 3
# -----------------------------
# Station Name: 20 Charles St E
# Latitude: 43.6691099
# Longitude: -79.38551
# Number of Bikes: 0
# -----------------------------
# Station Name: Niagara St / Tecumseth St
# Latitude: 43.641389
# Longitude: -79.404444
# Number of Bikes: 6
# -----------------------------
# Station Name: 424 Wellington St W
# Latitude: 43.643834
# Longitude: -79.396649
# Number of Bikes: 10
# -----------------------------
# Station Name: Dundas St W / St. Patrick St
# Latitude: 43.6545174
# Longitude: -79.3895315
# Number of Bikes: 10
# -----------------------------
# Station Name: Robert St / Bloor St W - SMART
# Latitude: 43.665846
# Longitude: -79.404998
# Number of Bikes: 6
# -----------------------------
# Station Name: Queen St E / Hammersmith Ave
# Latitude: 43.671349
# Longitude: -79.29451
# Number of Bikes: 10
# -----------------------------
# Station Name: Queen St. E / Eastern Ave
# Latitude: 43.667208
# Longitude: -79.312315
# Number of Bikes: 7
# -----------------------------
# Station Name: Hubbard Blvd / Balsam Av
# Latitude: 43.669328
# Longitude: -79.288949
# Number of Bikes: 11
# -----------------------------
# Station Name: Queen St. E / Spruce Hill Rd.
# Latitude: 43.672571
# Longitude: -79.289
# Number of Bikes: 6
# -----------------------------
# Station Name: Lower Spadina Ave / Lake Shore Blvd W
# Latitude: 43.638497
# Longitude: -79.39192
# Number of Bikes: 13
# -----------------------------
# Station Name: Lower Coxwell Ave /  Lake Shore Blvd E
# Latitude: 43.662771
# Longitude: -79.315223
# Number of Bikes: 10
# -----------------------------
# Station Name: Amelia St / Sumach St
# Latitude: 43.66852
# Longitude: -79.363525
# Number of Bikes: 2
# -----------------------------
# Station Name: Augusta Ave / Dundas St W
# Latitude: 43.652473
# Longitude: -79.401456
# Number of Bikes: 9
# -----------------------------
# Station Name: Queen St W / Ossington Ave
# Latitude: 43.643975
# Longitude: -79.419576
# Number of Bikes: 16
# -----------------------------
# Station Name: Trinity St /Front St E
# Latitude: 43.651318
# Longitude: -79.36023
# Number of Bikes: 15
# -----------------------------
# Station Name: Dundas St W / Yonge St
# Latitude: 43.656094
# Longitude: -79.381484
# Number of Bikes: 30
# -----------------------------
# Station Name: Kendal Ave / Spadina Rd
# Latitude: 43.670318
# Longitude: -79.405181
# Number of Bikes: 0
# -----------------------------
# Station Name: Davenport Rd / Bathurst St
# Latitude: 43.676667
# Longitude: -79.416111
# Number of Bikes: 3
# -----------------------------
# Station Name: Queen St W / Close Ave
# Latitude: 43.640634
# Longitude: -79.435841
# Number of Bikes: 15
# -----------------------------
# Station Name: King St W / Joe Shuster Way
# Latitude: 43.639444
# Longitude: -79.423611
# Number of Bikes: 23
# -----------------------------
# Station Name: Yarmouth Rd / Christie St
# Latitude: 43.67
# Longitude: -79.42083333333333
# Number of Bikes: 1
# -----------------------------
# Station Name: Palmerston Ave / Vermont Ave
# Latitude: 43.671389
# Longitude: -79.416389
# Number of Bikes: 3
# -----------------------------
# Station Name: Christie St / Benson Ave (Wychwood Barns)
# Latitude: 43.68
# Longitude: -79.42500000000001
# Number of Bikes: 9
# -----------------------------
# Station Name: King St W / Fraser Ave
# Latitude: 43.6394444
# Longitude: -79.42527777777778
# Number of Bikes: 15
# -----------------------------
# Station Name: Macpherson Ave / Spadina Rd
# Latitude: 43.675791
# Longitude: -79.40698
# Number of Bikes: 8
# -----------------------------
# Station Name: Bridgman Ave / Kendal Ave
# Latitude: 43.675556
# Longitude: -79.410278
# Number of Bikes: 7
# -----------------------------
# Station Name: Bridgman Ave / Bathurst St
# Latitude: 43.674444
# Longitude: -79.414722
# Number of Bikes: 8
# -----------------------------
# Station Name: Kendal Ave / Bernard Ave
# Latitude: 43.671513
# Longitude: -79.408317
# Number of Bikes: 0
# -----------------------------
# Station Name: Pretoria Ave / Broadview Ave
# Latitude: 43.6783213
# Longitude: -79.35822
# Number of Bikes: 5
# -----------------------------
# Station Name: Broadview Ave / Westwood Ave
# Latitude: 43.6848652
# Longitude: -79.356602
# Number of Bikes: 6
# -----------------------------
# Station Name: Fulton Ave / Pape Ave
# Latitude: 43.68395
# Longitude: -79.347046
# Number of Bikes: 1
# -----------------------------
# Station Name: Cosburn Ave / Donlands Ave
# Latitude: 43.690537
# Longitude: -79.341307
# Number of Bikes: 1
# -----------------------------
# Station Name: Beltline Trail / Chaplin Cres
# Latitude: 43.704461
# Longitude: -79.423122
# Number of Bikes: 5
# -----------------------------
# Station Name: Lake Shore Blvd E / Leslie St
# Latitude: 43.659195
# Longitude: -79.329196
# Number of Bikes: 17
# -----------------------------
# Station Name: King St E / Berkeley St
# Latitude: 43.651885
# Longitude: -79.3649
# Number of Bikes: 17
# -----------------------------
# Station Name: Rosedale Park (20 Scholfield Ave)
# Latitude: 43.682645
# Longitude: -79.377557
# Number of Bikes: 3
# -----------------------------
# Station Name: Mary McCormick Rec Centre (Sheridan Ave)
# Latitude: 43.6475
# Longitude: -79.43305555555555
# Number of Bikes: 12
# -----------------------------
# Station Name: Soho St / Queen St W
# Latitude: 43.6494896
# Longitude: -79.393535
# Number of Bikes: 7
# -----------------------------
# Station Name: Davenport Rd / Lansdowne Ave
# Latitude: 43.671526
# Longitude: -79.44874
# Number of Bikes: 1
# -----------------------------
# Station Name: Front St W / University Ave (2)
# Latitude: 43.6452972
# Longitude: -79.3827914
# Number of Bikes: 16
# -----------------------------
# Station Name: 457 King St W
# Latitude: 43.6452091
# Longitude: -79.3960744
# Number of Bikes: 17
# -----------------------------
# Station Name: Dufferin St / Sylvan Av (Dufferin Grove Park)
# Latitude: 43.6555556
# Longitude: -79.43361111111112
# Number of Bikes: 13
# -----------------------------
# Station Name: Roxborough St W / Yonge St
# Latitude: 43.678077
# Longitude: -79.390328
# Number of Bikes: 2
# -----------------------------
# Station Name: Crawford St / Queen St W
# Latitude: 43.645665
# Longitude: -79.415345
# Number of Bikes: 18
# -----------------------------
# Station Name: Lisgar St / Dundas St W - SMART
# Latitude: 43.6493472
# Longitude: -79.42668
# Number of Bikes: 6
# -----------------------------
# Station Name: Dundas St E / Regent Park Blvd
# Latitude: 43.660207
# Longitude: -79.361275
# Number of Bikes: 6
# -----------------------------
# Station Name: Lower Sherbourne St / The Esplanade
# Latitude: 43.648655
# Longitude: -79.367061
# Number of Bikes: 16
# -----------------------------
# Station Name: Nelson St / Duncan St
# Latitude: 43.648711
# Longitude: -79.389728
# Number of Bikes: 22
# -----------------------------
# Station Name: Jimmie Simpson Park (Queen St E)
# Latitude: 43.6605603
# Longitude: -79.3437663
# Number of Bikes: 10
# -----------------------------
# Station Name: Queen St E / Sackville St
# Latitude: 43.6561111
# Longitude: -79.36138888888888
# Number of Bikes: 4
# -----------------------------
# Station Name: Mill St / Tannery Rd
# Latitude: 43.652219
# Longitude: -79.354455
# Number of Bikes: 15
# -----------------------------
# Station Name: Cherry St / Distillery Ln
# Latitude: 43.650279
# Longitude: -79.356832
# Number of Bikes: 8
# -----------------------------
# Station Name: Queen St W / Spadina Ave
# Latitude: 43.649147
# Longitude: -79.395504
# Number of Bikes: 8
# -----------------------------
# Station Name: Yonge St / Harbour St
# Latitude: 43.643795
# Longitude: -79.375413
# Number of Bikes: 28
# -----------------------------
# Station Name: Willcocks St / St. George St
# Latitude: 43.662085
# Longitude: -79.397735
# Number of Bikes: 2
# -----------------------------
# Station Name: Dundas St E / Parliament St
# Latitude: 43.659575
# Longitude: -79.365769
# Number of Bikes: 5
# -----------------------------
# Station Name: 51 Parliament St
# Latitude: 43.65205
# Longitude: -79.362198
# Number of Bikes: 16
# -----------------------------
# Station Name: Queen's Park / Bloor St W
# Latitude: 43.668456
# Longitude: -79.393899
# Number of Bikes: 11
# -----------------------------
# Station Name: Fort York Blvd / Bathurst St - SMART
# Latitude: 43.639052
# Longitude: -79.399792
# Number of Bikes: 15
# -----------------------------
# Station Name: Alma Ave / Gladstone Ave SMART
# Latitude: 43.6448617
# Longitude: -79.42822
# Number of Bikes: 10
# -----------------------------
# Station Name: Queen St W / Cowan Ave
# Latitude: 43.6409
# Longitude: -79.432837
# Number of Bikes: 7
# -----------------------------
# Station Name: Harbord St / Clinton St
# Latitude: 43.660414
# Longitude: -79.415646
# Number of Bikes: 1
# -----------------------------
# Station Name: Central Tech  (Harbord St)
# Latitude: 43.661975
# Longitude: -79.407896
# Number of Bikes: 2
# -----------------------------
# Station Name: Roxton Rd / Harbord St
# Latitude: 43.65905
# Longitude: -79.422988
# Number of Bikes: 2
# -----------------------------
# Station Name: Ulster St / Bathurst St
# Latitude: 43.66
# Longitude: -79.4088888888889
# Number of Bikes: 0
# -----------------------------
# Station Name: Mortimer Ave / Coxwell Ave
# Latitude: 43.690564
# Longitude: -79.326319
# Number of Bikes: 1
# -----------------------------
# Station Name: Danforth Ave / Barrington Ave
# Latitude: 43.688325
# Longitude: -79.300463
# Number of Bikes: 8
# -----------------------------
# Station Name: Pacific Ave / Glenlake Ave
# Latitude: 43.65716
# Longitude: -79.46478
# Number of Bikes: 15
# -----------------------------
# Station Name: Broadview Subway Station
# Latitude: 43.6772
# Longitude: -79.35858
# Number of Bikes: 5
# -----------------------------
# Station Name: Church St  / Wood St
# Latitude: 43.662712
# Longitude: -79.379903
# Number of Bikes: 2
# -----------------------------
# Station Name: College Park - Gerrard Entrance
# Latitude: 43.658938
# Longitude: -79.383518
# Number of Bikes: 9
# -----------------------------
# Station Name: Danforth Ave / Coxwell Ave
# Latitude: 43.683378
# Longitude: -79.322961
# Number of Bikes: 8
# -----------------------------
# Station Name: 12 Harbour St
# Latitude: 43.6425636
# Longitude: -79.3762
# Number of Bikes: 15
# -----------------------------
# Station Name: Howard Park Ave / Dundas St W - SMART
# Latitude: 43.6521
# Longitude: -79.4486
# Number of Bikes: 2
# -----------------------------
# Station Name: Yonge St / Bloor St
# Latitude: 43.669969
# Longitude: -79.386532
# Number of Bikes: 0
# -----------------------------
# Station Name: Dufferin Gate - SMART
# Latitude: 43.633473
# Longitude: -79.425679
# Number of Bikes: 11
# -----------------------------
# Station Name: Lake Shore Blvd W / Ontario Dr
# Latitude: 43.630254
# Longitude: -79.420317
# Number of Bikes: 12
# -----------------------------
# Station Name: Bloor St W / Shaw St - SMART
# Latitude: 43.662403
# Longitude: -79.423098
# Number of Bikes: 1
# -----------------------------
# Station Name: Concord Ave / Dewson St
# Latitude: 43.656945
# Longitude: -79.424911
# Number of Bikes: 0
# -----------------------------
# Station Name: Hocken Ave / Vaughan Rd
# Latitude: 43.6817346
# Longitude: -79.4184725
# Number of Bikes: 2
# -----------------------------
# Station Name: St Clair Ave W / Bathurst St.
# Latitude: 43.683296
# Longitude: -79.418734
# Number of Bikes: 1
# -----------------------------
# Station Name: Queen St E / Nursewood Rd
# Latitude: 43.673831
# Longitude: -79.281455
# Number of Bikes: 13
# -----------------------------
# Station Name: Kewbeach Ave / Kenilworth Ave
# Latitude: 43.666325
# Longitude: -79.3014
# Number of Bikes: 16
# -----------------------------
# Station Name: Lakeview Ave / Harrison St (Green P) – SMART
# Latitude: 43.651145
# Longitude: -79.423742
# Number of Bikes: 0
# -----------------------------
# Station Name: Baldwin St / Spadina Ave - SMART
# Latitude: 43.654905
# Longitude: -79.398448
# Number of Bikes: 14
# -----------------------------
# Station Name: Frederick St / King St E
# Latitude: 43.651118
# Longitude: -79.369411
# Number of Bikes: 11
# -----------------------------
# Station Name: College St / Borden St
# Latitude: 43.6571
# Longitude: -79.4056
# Number of Bikes: 1
# -----------------------------
# Station Name: Beverley  St / Dundas St W
# Latitude: 43.652823
# Longitude: -79.393388
# Number of Bikes: 20
# -----------------------------
# Station Name: Bay St / St. Joseph St
# Latitude: 43.665527
# Longitude: -79.387499
# Number of Bikes: 1
# -----------------------------
# Station Name: Gould St / Mutual St
# Latitude: 43.6582
# Longitude: -79.3768
# Number of Bikes: 24
# -----------------------------
# Station Name: Riverdale Park North (Broadview Ave)
# Latitude: 43.671172
# Longitude: -79.354704
# Number of Bikes: 5
# -----------------------------
# Station Name: Danforth Ave / Ellerbeck St
# Latitude: 43.677076
# Longitude: -79.35667
# Number of Bikes: 7
# -----------------------------
# Station Name: Pape Subway Station (Green P)
# Latitude: 43.680223
# Longitude: -79.344062
# Number of Bikes: 1
# -----------------------------
# Station Name: Danforth Ave / Gough Ave
# Latitude: 43.678401
# Longitude: -79.346289
# Number of Bikes: 1
# -----------------------------
# Station Name: Danforth Ave / Lamb Ave
# Latitude: 43.681991
# Longitude: -79.329455
# Number of Bikes: 4
# -----------------------------
# Station Name: King St W / Stafford St
# Latitude: 43.6422222
# Longitude: -79.41111111111111
# Number of Bikes: 8
# -----------------------------
# Station Name: Bathurst St / Lennox St
# Latitude: 43.663808
# Longitude: -79.410491
# Number of Bikes: 0
# -----------------------------
# Station Name: Bathurst Subway Station
# Latitude: 43.6666667
# Longitude: -79.41166666666668
# Number of Bikes: 0
# -----------------------------
# Station Name: Bloor St W / Christie St
# Latitude: 43.6638889
# Longitude: -79.41888888888889
# Number of Bikes: 0
# -----------------------------
# Station Name: Ossington Ave / Bloor St W
# Latitude: 43.661705
# Longitude: -79.425734
# Number of Bikes: 1
# -----------------------------
# Station Name: Essex St / Christie St - SMART
# Latitude: 43.6686111
# Longitude: -79.42027777777778
# Number of Bikes: 0
# -----------------------------
# Station Name: Westmoreland Ave / Fernbank Ave
# Latitude: 43.665327
# Longitude: -79.43235
# Number of Bikes: 3
# -----------------------------
# Station Name: Havelock St / Dufferin Park
# Latitude: 43.657343
# Longitude: -79.43112
# Number of Bikes: 0
# -----------------------------
# Station Name: Bathurst St / Adelaide St W
# Latitude: 43.645324
# Longitude: -79.40345
# Number of Bikes: 8
# -----------------------------
# Station Name: Mill St / Parliament St
# Latitude: 43.650256
# Longitude: -79.36163
# Number of Bikes: 11
# -----------------------------
# Station Name: Ossington Ave / Harrison St
# Latitude: 43.651111111111106
# Longitude: -79.4213888888889
# Number of Bikes: 7
# -----------------------------
# Station Name: 80 Clinton St
# Latitude: 43.656296
# Longitude: -79.414663
# Number of Bikes: 3
# -----------------------------
# Station Name: Claremont St / Dundas St W
# Latitude: 43.651281
# Longitude: -79.411717
# Number of Bikes: 4
# -----------------------------
# Station Name: Rusholme Park Cres / College St
# Latitude: 43.65277778
# Longitude: -79.42972222
# Number of Bikes: 2
# -----------------------------
# Station Name: College St / Crawford St
# Latitude: 43.655
# Longitude: -79.418889
# Number of Bikes: 10
# -----------------------------
# Station Name: Queen St E / Alton Av
# Latitude: 43.663912
# Longitude: -79.327987
# Number of Bikes: 14
# -----------------------------
# Station Name: Simcoe St / Wellington St W North
# Latitude: 43.6462176
# Longitude: -79.3855048
# Number of Bikes: 14
# -----------------------------
# Station Name: Coxwell Ave / Plains Rd
# Latitude: 43.69595
# Longitude: -79.328535
# Number of Bikes: 14
# -----------------------------
# Station Name: Carlaw Ave / Strathcona Ave
# Latitude: 43.6753188
# Longitude: -79.3462789
# Number of Bikes: 0
# -----------------------------
# Station Name: Logan Ave / Bain Ave
# Latitude: 43.6720273
# Longitude: -79.3470557
# Number of Bikes: 10
# -----------------------------
# Station Name: Liberty St / Fraser Ave Green P
# Latitude: 43.637981
# Longitude: -79.424146
# Number of Bikes: 13
# -----------------------------
# Station Name: King St W / Douro St
# Latitude: 43.640885
# Longitude: -79.416379
# Number of Bikes: 2
# -----------------------------
# Station Name: Queen St E / Berkeley St
# Latitude: 43.6552778
# Longitude: -79.36583333333333
# Number of Bikes: 10
# -----------------------------
# Station Name: Howard St / Sherbourne St
# Latitude: 43.6712581
# Longitude: -79.376367
# Number of Bikes: 1
# -----------------------------
# Station Name: Carlton St / Parliament St
# Latitude: 43.664524
# Longitude: -79.36793
# Number of Bikes: 8
# -----------------------------
# Station Name: Sumach St / Carlton St (Riverdale Farm)
# Latitude: 43.665867
# Longitude: -79.362506
# Number of Bikes: 5
# -----------------------------
# Station Name: King St W / Bay St (East Side)
# Latitude: 43.648575
# Longitude: -79.380042
# Number of Bikes: 13
# -----------------------------
# Station Name: Front St W / Blue Jays Way
# Latitude: 43.643473
# Longitude: -79.390477
# Number of Bikes: 3
# -----------------------------
# Station Name: Metro Hall Plaza
# Latitude: 43.645859
# Longitude: -79.38783
# Number of Bikes: 6
# -----------------------------
# Station Name: Navy Wharf Crt / Bremner Blvd
# Latitude: 43.640722
# Longitude: -79.391051
# Number of Bikes: 7
# -----------------------------
# Station Name: Jarvis St / Carlton St
# Latitude: 43.66207
# Longitude: -79.37617
# Number of Bikes: 0
# -----------------------------
# Station Name: Lake Shore Blvd E / Knox Ave
# Latitude: 43.660206
# Longitude: -79.3244
# Number of Bikes: 7
# -----------------------------
# Station Name: Hubbard Blvd. / Glen Manor Dr.
# Latitude: 43.668633
# Longitude: -79.291162
# Number of Bikes: 15
# -----------------------------
# Station Name: Yonge St / Dundonald St - SMART
# Latitude: 43.665801
# Longitude: -79.384796
# Number of Bikes: 6
# -----------------------------
# Station Name: Bay St / Charles St W - SMART
# Latitude: 43.668153
# Longitude: -79.38891
# Number of Bikes: 0
# -----------------------------
# Station Name: Church St / Dundas St E - SMART
# Latitude: 43.657024
# Longitude: -79.377257
# Number of Bikes: 2
# -----------------------------
# Station Name: Yonge St / Alexander St - SMART
# Latitude: 43.662862
# Longitude: -79.383572
# Number of Bikes: 5
# -----------------------------
# Station Name: Eglinton Ave W / Henning Ave SMART
# Latitude: 43.7063473
# Longitude: -79.40161
# Number of Bikes: 1
# -----------------------------
# Station Name: Balliol St / Yonge St  SMART
# Latitude: 43.6978701
# Longitude: -79.39419
# Number of Bikes: 9
# -----------------------------
# Station Name: Frobisher Ave / Lascelles Blvd
# Latitude: 43.696708
# Longitude: -79.40045
# Number of Bikes: 1
# -----------------------------
# Station Name: Front St E / Scott St
# Latitude: 43.6476616
# Longitude: -79.37549
# Number of Bikes: 10
# -----------------------------
# Station Name: Frederick St / The Esplanade
# Latitude: 43.6487245
# Longitude: -79.36839
# Number of Bikes: 16
# -----------------------------
# Station Name: King St W / Bay St (West Side)
# Latitude: 43.64852
# Longitude: -79.380576
# Number of Bikes: 31
# -----------------------------
# Station Name: Elizabeth St / Edward St (Bus Terminal)
# Latitude: 43.656026
# Longitude: -79.385327
# Number of Bikes: 5
# -----------------------------
# Station Name: King St W / Spadina Ave
# Latitude: 43.645323
# Longitude: -79.395003
# Number of Bikes: 14
# -----------------------------
# Station Name: Glen Edyth Dr / Davenport Rd
# Latitude: 43.677778
# Longitude: -79.405556
# Number of Bikes: 5
# -----------------------------
# Station Name: Queens Quay / Yonge St
# Latitude: 43.641646
# Longitude: -79.375308
# Number of Bikes: 14
# -----------------------------
# Station Name: Front St W / Bay St (North Side)
# Latitude: 43.646162
# Longitude: -79.378912
# Number of Bikes: 11
# -----------------------------
# Station Name: Danforth Ave / Westlake Ave
# Latitude: 43.687323
# Longitude: -79.304848
# Number of Bikes: 4
# -----------------------------
# Station Name: Jarvis St / Isabella St
# Latitude: 43.668991
# Longitude: -79.379385
# Number of Bikes: 2
# -----------------------------
# Station Name: Yonge St / Wood St
# Latitude: 43.6622222
# Longitude: -79.3825
# Number of Bikes: 3
# -----------------------------
# Station Name: King St W / Tecumseth St
# Latitude: 43.64333333333333
# Longitude: -79.40555555555557
# Number of Bikes: 5
# -----------------------------
# Station Name: Beverley St / College St
# Latitude: 43.6575
# Longitude: -79.39527777777778
# Number of Bikes: 5
# -----------------------------
# Station Name: Gould St / Yonge St (TMU)
# Latitude: 43.657424
# Longitude: -79.381019
# Number of Bikes: 15
# -----------------------------
# Station Name: Front St W / Bay St (South Side)
# Latitude: 43.64595
# Longitude: -79.378761
# Number of Bikes: 15
# -----------------------------
# Station Name: Charles St W / Balmuto St - SMART
# Latitude: 43.668427
# Longitude: -79.38725
# Number of Bikes: 1
# -----------------------------
# Station Name: Charles St E / Jarvis St - SMART
# Latitude: 43.669604
# Longitude: -79.381171
# Number of Bikes: 0
# -----------------------------
# Station Name: Queen St E / Pape Ave - SMART
# Latitude: 43.661673
# Longitude: -79.337789
# Number of Bikes: 14
# -----------------------------
# Station Name: Gerrard St E / Broadview Ave  - SMART
# Latitude: 43.665656
# Longitude: -79.352055
# Number of Bikes: 15
# -----------------------------
# Station Name: Humber Bay Shores Park East
# Latitude: 43.6308933
# Longitude: -79.4722622
# Number of Bikes: 2
# -----------------------------
# Station Name: Humber Bay Shores Park West
# Latitude: 43.6224434
# Longitude: -79.480284
# Number of Bikes: 18
# -----------------------------
# Station Name: Taddle Creek Park
# Latitude: 43.66986
# Longitude: -79.398443
# Number of Bikes: 4
# -----------------------------
# Station Name: Thompson St / Broadview Ave - SMART
# Latitude: 43.659471
# Longitude: -79.350325
# Number of Bikes: 11
# -----------------------------
# Station Name: Roncesvalles Ave / Marmaduke St
# Latitude: 43.650492
# Longitude: -79.450842
# Number of Bikes: 0
# -----------------------------
# Station Name: Queen St W  /  Fuller Ave - SMART
# Latitude: 43.640255
# Longitude: -79.439223
# Number of Bikes: 14
# -----------------------------
# Station Name: King St W / Cowan Ave - SMART
# Latitude: 43.637922
# Longitude: -79.431734
# Number of Bikes: 3
# -----------------------------
# Station Name: Garden Ave / Roncesvalles Ave
# Latitude: 43.643769
# Longitude: -79.447915
# Number of Bikes: 16
# -----------------------------
# Station Name: Sorauren Ave / Geoffrey St - SMART
# Latitude: 43.649172
# Longitude: -79.4445087
# Number of Bikes: 0
# -----------------------------
# Station Name: Bloor St W / Manning Ave - SMART
# Latitude: 43.663912
# Longitude: -79.416124
# Number of Bikes: 3
# -----------------------------
# Station Name: Mallon Ave / Jones Ave -SMART
# Latitude: 43.66587
# Longitude: -79.33443
# Number of Bikes: 12
# -----------------------------
# Station Name: Berkeley St / Dundas St E - SMART
# Latitude: 43.658816
# Longitude: -79.367318
# Number of Bikes: 12
# -----------------------------
# Station Name: 128 Sterling Rd - SMART
# Latitude: 43.654004
# Longitude: -79.444792
# Number of Bikes: 7
# -----------------------------
# Station Name: Sunnyside Ave / The Queensway - SMART
# Latitude: 43.6397
# Longitude: -79.44865
# Number of Bikes: 14
# -----------------------------
# Station Name: Sackville St / Eastern Ave - SMART
# Latitude: 43.653809
# Longitude: -79.3595
# Number of Bikes: 7
# -----------------------------
# Station Name: Davenport Rd / McAlpine St - SMART
# Latitude: 43.673768
# Longitude: -79.391253
# Number of Bikes: 1
# -----------------------------
# Station Name: Sumach St  / Queen St E
# Latitude: 43.656638
# Longitude: -79.358749
# Number of Bikes: 14
# -----------------------------
# Station Name: Blythwood Rd / Yonge St - SMART
# Latitude: 43.716652
# Longitude: -79.399993
# Number of Bikes: 1
# -----------------------------
# Station Name: Gerrard St E / Main St
# Latitude: 43.684261
# Longitude: -79.299332
# Number of Bikes: 2
# -----------------------------
# Station Name: Southwood Dr / Kingston Rd - SMART
# Latitude: 43.678685
# Longitude: -79.297974
# Number of Bikes: 3
# -----------------------------
# Station Name: Neil McLellan Park
# Latitude: 43.65143
# Longitude: -79.47779
# Number of Bikes: 2
# -----------------------------
# Station Name: Jane St / Bloor St W (Jane Subway Station)
# Latitude: 43.64976
# Longitude: -79.48477
# Number of Bikes: 2
# -----------------------------
# Station Name: Antler St / Campbell Ave - SMART
# Latitude: 43.664182
# Longitude: -79.449066
# Number of Bikes: 0
# -----------------------------
# Station Name: Clarence Square
# Latitude: 43.64407
# Longitude: -79.3929
# Number of Bikes: 21
# -----------------------------
# Station Name: Lake Shore Blvd W / Louisa St
# Latitude: 43.61868
# Longitude: -79.48674
# Number of Bikes: 8
# -----------------------------
# Station Name: Front St W / Simcoe St
# Latitude: 43.6442
# Longitude: -79.38702
# Number of Bikes: 7
# -----------------------------
# Station Name: Lower Simcoe St / Bremner Blvd
# Latitude: 43.64283
# Longitude: -79.38409
# Number of Bikes: 7
# -----------------------------
# Station Name: Glendonwynne Rd / Bloor St W
# Latitude: 43.65182
# Longitude: -79.47421
# Number of Bikes: 9
# -----------------------------
# Station Name: Russell Hill Rd / St Clair Ave W
# Latitude: 43.685569
# Longitude: -79.408019
# Number of Bikes: 2
# -----------------------------
# Station Name: Church St / Lombard St
# Latitude: 43.651678
# Longitude: -79.375233
# Number of Bikes: 14
# -----------------------------
# Station Name: Richmond St E / Yonge St
# Latitude: 43.651838
# Longitude: -79.378743
# Number of Bikes: 10
# -----------------------------
# Station Name: Queen's Park Cres W / Hoskin Ave
# Latitude: 43.665221
# Longitude: -79.394009
# Number of Bikes: 10
# -----------------------------
# Station Name: Pottery Rd / Lower Don River Trail
# Latitude: 43.688148
# Longitude: -79.362101
# Number of Bikes: 6
# -----------------------------
# Station Name: Bleecker St / St James Ave
# Latitude: 43.669232
# Longitude: -79.374495
# Number of Bikes: 7
# -----------------------------
# Station Name: Western Battery Rd / Pirandello St
# Latitude: 43.640075
# Longitude: -79.414156
# Number of Bikes: 9
# -----------------------------
# Station Name: Carlaw Ave / Danforth Ave
# Latitude: 43.678285
# Longitude: -79.347346
# Number of Bikes: 3
# -----------------------------
# Station Name: Cosburn Ave / Cedarvale Ave
# Latitude: 43.697139
# Longitude: -79.31469
# Number of Bikes: 1
# -----------------------------
# Station Name: Goodwood Park Crt / Dentonia Park
# Latitude: 43.694826
# Longitude: -79.295208
# Number of Bikes: 1
# -----------------------------
# Station Name: Eastwood Rd / Coxwell Ave
# Latitude: 43.673118
# Longitude: -79.318651
# Number of Bikes: 7
# -----------------------------
# Station Name: Trent Ave / Danforth Ave
# Latitude: 43.689293
# Longitude: -79.295895
# Number of Bikes: 10
# -----------------------------
# Station Name: Orchard Park
# Latitude: 43.66908
# Longitude: -79.3149
# Number of Bikes: 8
# -----------------------------
# Station Name: Clendenan Ave / Rowland St - SMART
# Latitude: 43.66073
# Longitude: -79.47149
# Number of Bikes: 9
# -----------------------------
# Station Name: Concord Ave / Bloor St W
# Latitude: 43.66189
# Longitude: -79.42679
# Number of Bikes: 2
# -----------------------------
# Station Name: Gothic Ave / Quebec Ave
# Latitude: 43.65389
# Longitude: -79.4675
# Number of Bikes: 13
# -----------------------------
# Station Name: Via Italia / Mackay Ave
# Latitude: 43.676697
# Longitude: -79.445029
# Number of Bikes: 1
# -----------------------------
# Station Name: Rushton Rd / St Clair Ave W
# Latitude: 43.68114
# Longitude: -79.4277
# Number of Bikes: 0
# -----------------------------
# Station Name: Dundas St E / Boulton Ave - SMART
# Latitude: 43.663148
# Longitude: -79.347938
# Number of Bikes: 3
# -----------------------------
# Station Name: Gerrard St E / Leslie St
# Latitude: 43.669813
# Longitude: -79.3335
# Number of Bikes: 10
# -----------------------------
# Station Name: Marilyn Bell Park Tennis Court
# Latitude: 43.633537
# Longitude: -79.437461
# Number of Bikes: 3
# -----------------------------
# Station Name: The Queensway at South Kingsway
# Latitude: 43.63632
# Longitude: -79.47307
# Number of Bikes: 17
# -----------------------------
# Station Name: Merton St / Mount Pleasant Rd
# Latitude: 43.697819
# Longitude: -79.38786
# Number of Bikes: 8
# -----------------------------
# Station Name: Tyndall Ave / King St W - SMART
# Latitude: 43.638426
# Longitude: -79.429142
# Number of Bikes: 9
# -----------------------------
# Station Name: College Park - Yonge St Entrance
# Latitude: 43.65988
# Longitude: -79.38279
# Number of Bikes: 5
# -----------------------------
# Station Name: Barton Ave / Howland Ave - SMART
# Latitude: 43.66842
# Longitude: -79.410585
# Number of Bikes: 1
# -----------------------------
# Station Name: Keele St / Annette St
# Latitude: 43.66402
# Longitude: -79.46418
# Number of Bikes: 4
# -----------------------------
# Station Name: Keele St / Vine Ave
# Latitude: 43.66686
# Longitude: -79.46526
# Number of Bikes: 5
# -----------------------------
# Station Name: Howard St / Rose Ave
# Latitude: 43.671278
# Longitude: -79.372127
# Number of Bikes: 0
# -----------------------------
# Station Name: Little Norway Park
# Latitude: 43.635023
# Longitude: -79.399505
# Number of Bikes: 21
# -----------------------------
# Station Name: Isabella St / Church St
# Latitude: 43.66834
# Longitude: -79.38235
# Number of Bikes: 0
# -----------------------------
# Station Name: Lascelles Blvd / Eglinton Ave W
# Latitude: 43.70547
# Longitude: -79.40355
# Number of Bikes: 0
# -----------------------------
# Station Name: Polson Pier
# Latitude: 43.641675
# Longitude: -79.354006
# Number of Bikes: 1
# -----------------------------
# Station Name: Dentonia Park
# Latitude: 43.694341
# Longitude: -79.291416
# Number of Bikes: 3
# -----------------------------
# Station Name: Lower Jarvis St / Queens Quay E
# Latitude: 43.64422
# Longitude: -79.36927
# Number of Bikes: 15
# -----------------------------
# Station Name: Summerhill Ave / Maclennan Ave
# Latitude: 43.685924
# Longitude: -79.376304
# Number of Bikes: 0
# -----------------------------
# Station Name: Queens Quay E / Lower Sherbourne St
# Latitude: 43.645215
# Longitude: -79.364898
# Number of Bikes: 1
# -----------------------------
# Station Name: Wright Ave / Sorauren Ave - SMART
# Latitude: 43.646677
# Longitude: -79.442741
# Number of Bikes: 1
# -----------------------------
# Station Name: Ellis Ave / The Queensway
# Latitude: 43.63855
# Longitude: -79.46693
# Number of Bikes: 12
# -----------------------------
# Station Name: High Park - Grenadier Cafe
# Latitude: 43.645599
# Longitude: -79.4657123
# Number of Bikes: 5
# -----------------------------
# Station Name: Winona Dr / Davenport Rd
# Latitude: 43.674923
# Longitude: -79.430465
# Number of Bikes: 3
# -----------------------------
# Station Name: Danforth Ave / Aldridge Ave
# Latitude: 43.684758
# Longitude: -79.316767
# Number of Bikes: 0
# -----------------------------
# Station Name: Dundonald St / Church St
# Latitude: 43.66663
# Longitude: -79.38148
# Number of Bikes: 20
# -----------------------------
# Station Name: Gerrard St E / Malvern Ave - SMART
# Latitude: 43.685221
# Longitude: -79.294766
# Number of Bikes: 4
# -----------------------------
# Station Name: Bathurst St/Queens Quay(Billy Bishop Airport)
# Latitude: 43.635492
# Longitude: -79.398253
# Number of Bikes: 31
# -----------------------------
# Station Name: Queens Quay W / Lower Simcoe St
# Latitude: 43.63951
# Longitude: -79.383717
# Number of Bikes: 0
# -----------------------------
# Station Name: Bremner Blvd / Rees St
# Latitude: 43.641529
# Longitude: -79.386741
# Number of Bikes: 16
# -----------------------------
# Station Name: King St W / Crawford St
# Latitude: 43.6417852
# Longitude: -79.4131148
# Number of Bikes: 7
# -----------------------------
# Station Name: Yonge St / Dundas Sq
# Latitude: 43.655766
# Longitude: -79.3802
# Number of Bikes: 25
# -----------------------------
# Station Name: St Clair Ave W / Winona Dr
# Latitude: 43.680466
# Longitude: -79.432522
# Number of Bikes: 4
# -----------------------------
# Station Name: Bay St / Wellesley St W
# Latitude: 43.664088
# Longitude: -79.387095
# Number of Bikes: 19
# -----------------------------
# Station Name: Humberside Grounds - SMART
# Latitude: 43.65917
# Longitude: -79.46997
# Number of Bikes: 9
# -----------------------------
# Station Name: Bloor St E / Huntley St - SMART
# Latitude: 43.671535
# Longitude: -79.379173
# Number of Bikes: 3
# -----------------------------
# Station Name: Wellington St W / York St
# Latitude: 43.646734
# Longitude: -79.38301
# Number of Bikes: 16
# -----------------------------
# Station Name: Dalton Rd / Bloor St W
# Latitude: 43.6662942
# Longitude: -79.4066433
# Number of Bikes: 2
# -----------------------------
# Station Name: Davenport Rd / Christie St
# Latitude: 43.675278
# Longitude: -79.423889
# Number of Bikes: 0
# -----------------------------
# Station Name: King St W / Jordan St
# Latitude: 43.648928
# Longitude: -79.378623
# Number of Bikes: 7
# -----------------------------
# Station Name: E.T. Seton Park (Eglinton Ave E / Leslie St)
# Latitude: 43.715951
# Longitude: -79.351246
# Number of Bikes: 1
# -----------------------------
# Station Name: Woodbine Ave / Lake Shore Blvd E
# Latitude: 43.665645
# Longitude: -79.304711
# Number of Bikes: 26
# -----------------------------
# Station Name: King St W / Charlotte St
# Latitude: 43.645572
# Longitude: -79.39399
# Number of Bikes: 19
# -----------------------------
# Station Name: Jarvis St / Richmond St E
# Latitude: 43.652777
# Longitude: -79.372637
# Number of Bikes: 2
# -----------------------------
# Station Name: Symington Ave / Dupont St
# Latitude: 43.665538
# Longitude: -79.451263
# Number of Bikes: 1
# -----------------------------
# Station Name: King St E / Jarvis St
# Latitude: 43.650325
# Longitude: -79.372287
# Number of Bikes: 19
# -----------------------------
# Station Name: Bay St / Bloor St W (East Side)
# Latitude: 43.66943
# Longitude: -79.38915
# Number of Bikes: 13
# -----------------------------
# Station Name: Bay St / Bloor St W (West Side)
# Latitude: 43.669244
# Longitude: -79.3894
# Number of Bikes: 4
# -----------------------------
# Station Name: Wells Hill Ave / St Clair Ave W
# Latitude: 43.683351
# Longitude: -79.41562
# Number of Bikes: 1
# -----------------------------
# Station Name: Dundas St E / George St
# Latitude: 43.6574766
# Longitude: -79.373446
# Number of Bikes: 4
# -----------------------------
# Station Name: Fleet St / Bathurst St
# Latitude: 43.636611
# Longitude: -79.400042
# Number of Bikes: 14
# -----------------------------
# Station Name: Tecumseth St / Queen St W - SMART
# Latitude: 43.646552
# Longitude: -79.406468
# Number of Bikes: 1
# -----------------------------
# Station Name: Briar Hill Ave / Yonge St - SMART
# Latitude: 43.713524
# Longitude: -79.400162
# Number of Bikes: 2
# -----------------------------
# Station Name: King St E / Church St
# Latitude: 43.65003919999999
# Longitude: -79.3733541
# Number of Bikes: 13
# -----------------------------
# Station Name: Bay St / Albert St
# Latitude: 43.653264
# Longitude: -79.382458
# Number of Bikes: 33
# -----------------------------
# Station Name: Wellesley St W / Queen's Park Cres
# Latitude: 43.663376
# Longitude: -79.392125
# Number of Bikes: 7
# -----------------------------
# Station Name: Bay St / College St (East Side)
# Latitude: 43.660439
# Longitude: -79.385525
# Number of Bikes: 10
# -----------------------------
# Station Name: University Ave / College St (East)
# Latitude: 43.65995
# Longitude: -79.38964
# Number of Bikes: 1
# -----------------------------
# Station Name: Bay St / College St (West Side) - SMART
# Latitude: 43.660087
# Longitude: -79.385655
# Number of Bikes: 3
# -----------------------------
# Station Name: Superior Ave / Lake Shore Blvd W
# Latitude: 43.6146692
# Longitude: -79.4873148
# Number of Bikes: 10
# -----------------------------
# Station Name: Humber Bay Shores Park / Marine Parade Dr
# Latitude: 43.626265
# Longitude: -79.476723
# Number of Bikes: 22
# -----------------------------
# Station Name: Lake Shore Blvd W / Colborne Lodge Dr
# Latitude: 43.63771
# Longitude: -79.458173
# Number of Bikes: 12
# -----------------------------
# Station Name: Ripley Ave / Ormskirk Ave
# Latitude: 43.6390437
# Longitude: -79.4760109
# Number of Bikes: 20
# -----------------------------
# Station Name: St Clarens Ave / Shirley St
# Latitude: 43.6486599
# Longitude: -79.4376413
# Number of Bikes: 4
# -----------------------------
# Station Name: Lisgar Park
# Latitude: 43.6423847
# Longitude: -79.4240277
# Number of Bikes: 7
# -----------------------------
# Station Name: Bartlett Parkette
# Latitude: 43.6702236
# Longitude: -79.4360232
# Number of Bikes: 14
# -----------------------------
# Station Name: Sherbourne St N / Elm Ave
# Latitude: 43.6752732
# Longitude: -79.3778458
# Number of Bikes: 2
# -----------------------------
# Station Name: Walnut Ave / Queen St W
# Latitude: 43.645469
# Longitude: -79.411084
# Number of Bikes: 12
# -----------------------------
# Station Name: Vaughan Rd /Wychwood Ave
# Latitude: 43.6882821
# Longitude: -79.4253856
# Number of Bikes: 2
# -----------------------------
# Station Name: Palmerston Ave / Dundas St W
# Latitude: 43.651603
# Longitude: -79.408346
# Number of Bikes: 5
# -----------------------------
# Station Name: 541 Huron St - SMART
# Latitude: 43.670206
# Longitude: -79.402643
# Number of Bikes: 6
# -----------------------------
# Station Name: Euclid Ave / Herrick St - SMART
# Latitude: 43.661559
# Longitude: -79.413845
# Number of Bikes: 1
# -----------------------------
# Station Name: Baldwin St / Henry St
# Latitude: 43.6560758
# Longitude: -79.393259
# Number of Bikes: 9
# -----------------------------
# Station Name: Orde St / McCaul St
# Latitude: 43.6580442
# Longitude: -79.3927404
# Number of Bikes: 4
# -----------------------------
# Station Name: Ross St / Cecil St - SMART
# Latitude: 43.6568254
# Longitude: -79.3966159
# Number of Bikes: 8
# -----------------------------
# Station Name: Lake Shore Blvd W / Thirty Ninth Street
# Latitude: 43.5927419
# Longitude: -79.54033009999999
# Number of Bikes: 9
# -----------------------------
# Station Name: Lake Shore Blvd W / Twenty Fourth St
# Latitude: 43.597082
# Longitude: -79.522768
# Number of Bikes: 6
# -----------------------------
# Station Name: Windsor St / Newcastle St
# Latitude: 43.6171635
# Longitude: -79.4971065
# Number of Bikes: 3
# -----------------------------
# Station Name: Royal York Rd / Mimico Ave
# Latitude: 43.612063
# Longitude: -79.496573
# Number of Bikes: 2
# -----------------------------
# Station Name: Berry Rd / Bell Manor Dr
# Latitude: 43.63732
# Longitude: -79.489083
# Number of Bikes: 12
# -----------------------------
# Station Name: Humber College
# Latitude: 43.5961692
# Longitude: -79.5160575
# Number of Bikes: 16
# -----------------------------
# Station Name: Amos Waites Park
# Latitude: 43.613606
# Longitude: -79.4883535
# Number of Bikes: 15
# -----------------------------
# Station Name: Priscilla Ave / Dundas St W
# Latitude: 43.664665
# Longitude: -79.489385
# Number of Bikes: 5
# -----------------------------
# Station Name: Durie St / Dundas St W
# Latitude: 43.665523
# Longitude: -79.484892
# Number of Bikes: 1
# -----------------------------
# Station Name: St Clair Ave W / Castleton Ave
# Latitude: 43.668496
# Longitude: -79.485426
# Number of Bikes: 4
# -----------------------------
# Station Name: Weston Lions Park
# Latitude: 43.698841
# Longitude: -79.519472
# Number of Bikes: 14
# -----------------------------
# Station Name: Annette St / Jane St
# Latitude: 43.658574
# Longitude: -79.487246
# Number of Bikes: 7
# -----------------------------
# Station Name: Jameson Ave / Queen St W
# Latitude: 43.63985
# Longitude: -79.43703
# Number of Bikes: 6
# -----------------------------
# Station Name: Carlaw Ave / Dundas St E
# Latitude: 43.665076
# Longitude: -79.341509
# Number of Bikes: 4
# -----------------------------
# Station Name: Toronto Inukshuk Park
# Latitude: 43.6323994
# Longitude: -79.40978179999999
# Number of Bikes: 33
# -----------------------------
# Station Name: Cosburn Ave / Durant Ave
# Latitude: 43.6935477
# Longitude: -79.3301658
# Number of Bikes: 2
# -----------------------------
# Station Name: Swansea Community Centre
# Latitude: 43.6438036
# Longitude: -79.4770327
# Number of Bikes: 10
# -----------------------------
# Station Name: Bellwoods Ave / Treford Pl - SMART
# Latitude: 43.65246
# Longitude: -79.413528
# Number of Bikes: 1
# -----------------------------
# Station Name: Bayview Ave / Lawren Harris Square
# Latitude: 43.6548521
# Longitude: -79.35397680000001
# Number of Bikes: 2
# -----------------------------
# Station Name: The Queensway / High St
# Latitude: 43.630874
# Longitude: -79.482407
# Number of Bikes: 3
# -----------------------------
# Station Name: Symington Ave / Davenport Rd
# Latitude: 43.6704403
# Longitude: -79.45328549999999
# Number of Bikes: 0
# -----------------------------
# Station Name: Front St E / Bayview Avenue
# Latitude: 43.6535
# Longitude: -79.354068
# Number of Bikes: 5
# -----------------------------
# Station Name: Oak St / Sumach St
# Latitude: 43.6617908
# Longitude: -79.361515
# Number of Bikes: 5
# -----------------------------
# Station Name: The Esplanade / Hahn Pl
# Latitude: 43.649709
# Longitude: -79.364184
# Number of Bikes: 12
# -----------------------------
# Station Name: 439 Sherbourne St
# Latitude: 43.666051
# Longitude: -79.374161
# Number of Bikes: 9
# -----------------------------
# ...
# Number of Bikes: 4
# -----------------------------
# Station Name: Yonge St / Montgomery Ave - SMART
# Latitude: 43.70960859570095
# Longitude: -79.39915125005619
# Number of Bikes: 2
# -----------------------------
# Station Name: 552 Birchmount Rd
# Latitude: 43.71176278859601
# Longitude: -79.27028152889692
# Number of Bikes: 6
# -----------------------------
# Station Name: Highfield Rd / Gerrard St E
# Latitude: 43.671771
# Longitude: -79.324961
# Number of Bikes: 15
# -----------------------------
# Station Name: Eastgate Cres / Pharmacy Ave
# Latitude: 43.7110442448186
# Longitude: -79.29127313845584
# Number of Bikes: 2
# -----------------------------
# Station Name: Firvalley Ct / Warden Ave
# Latitude: 43.7032112
# Longitude: -79.2787149
# Number of Bikes: 8
# -----------------------------
# Station Name: Midland Ave / Kingston Rd
# Latitude: 43.7128578
# Longitude: -79.2487086
# Number of Bikes: 5
# -----------------------------
# Station Name: Bellamy Rd S / Kingston Rd
# Latitude: 43.7323277855009
# Longitude: -79.22496619876934
# Number of Bikes: 3
# -----------------------------
# Station Name: Avenue Rd / Cumberland St
# Latitude: 43.669821695059376
# Longitude: -79.39444614603269
# Number of Bikes: 11
# -----------------------------
# Station Name: Fenwood Ht / Kingston Rd
# Latitude: 43.72690169821676
# Longitude: -79.22920396582664
# Number of Bikes: 14
# -----------------------------
# Station Name: Avenue Rd / Macpherson Ave
# Latitude: 43.67794376009951
# Longitude: -79.39836278587889
# Number of Bikes: 3
# -----------------------------
# Station Name: Dufferin St / Queen St W
# Latitude: 43.64309687937765
# Longitude: -79.42875613770637
# Number of Bikes: 4
# -----------------------------
# Station Name: Bay St / Dundas St W
# Latitude: 43.655350778457056
# Longitude: -79.38345966759798
# Number of Bikes: 21
# -----------------------------
# Station Name: Shaw St / King St W
# Latitude: 43.6412561641921
# Longitude: -79.41502994047545
# Number of Bikes: 9
# -----------------------------
# Station Name: Portland St / Queen St W
# Latitude: 43.6476
# Longitude: -79.4015
# Number of Bikes: 11
# -----------------------------
# Station Name: Yonge St / Merton St
# Latitude: 43.6962750705313
# Longitude: -79.39629396191867
# Number of Bikes: 3
# -----------------------------
# Station Name: Soudan Ave / Yonge St
# Latitude: 43.70430959999999
# Longitude: -79.3972815
# Number of Bikes: 2
# -----------------------------
# Station Name: Avenue Rd / Oxton Ave
# Latitude: 43.69711160305226
# Longitude: -79.40537298227844
# Number of Bikes: 0
# -----------------------------
# Station Name: 1612 Danforth Ave
# Latitude: 43.68370788065334
# Longitude: -79.32262453633884
# Number of Bikes: 1
# -----------------------------
# Station Name: Lisgar St / Queen St W - SMART
# Latitude: 43.64299174164139
# Longitude: -79.42355911563249
# Number of Bikes: 10
# -----------------------------
# Station Name: Leslie St / Commissioners St
# Latitude: 43.657275497390124
# Longitude: -79.32661544194183
# Number of Bikes: 17
# -----------------------------
# Station Name: Greenwood Ave / Sammon Ave
# Latitude: 43.68698672516659
# Longitude: -79.33478198280334
# Number of Bikes: 1
# -----------------------------
# Station Name: Lansdowne Subway Station
# Latitude: 43.65922918158098
# Longitude: -79.44320901022282
# Number of Bikes: 0
# -----------------------------
# Station Name: Warden Subway Station
# Latitude: 43.71161098023304
# Longitude: -79.28055565662231
# Number of Bikes: 16
# -----------------------------
# Station Name: Kingston Rd / Scarborough Golf Club Rd
# Latitude: 43.74531103700256
# Longitude: -79.20970650787817
# Number of Bikes: 8
# -----------------------------
# Station Name: Wellington St W / Bay St
# Latitude: 43.647259
# Longitude: -79.379878
# Number of Bikes: 14
# -----------------------------
# Station Name: Greenwood Ave / Gerrard St E
# Latitude: 43.67036917803197
# Longitude: -79.32782698645094
# Number of Bikes: 8
# -----------------------------
# Station Name: Simcoe St / Wellington St W South
# Latitude: 43.6458569
# Longitude: -79.3853654
# Number of Bikes: 24
# -----------------------------
# Station Name: George St / King St E
# Latitude: 43.6509552
# Longitude: -79.3707
# Number of Bikes: 15
# -----------------------------
# Station Name: Dundas St W / Crawford St
# Latitude: 43.649722
# Longitude: -79.416944
# Number of Bikes: 27
# -----------------------------
# Station Name: Ossington Ave / Bruce St
# Latitude: 43.64570236705167
# Longitude: -79.41933192053696
# Number of Bikes: 14
# -----------------------------
# Station Name: Bloor St W / Balmuto St
# Latitude: 43.66981064282057
# Longitude: -79.38801106873031
# Number of Bikes: 3
# -----------------------------
# Station Name: Parliament St / Aberdeen Ave
# Latitude: 43.665278
# Longitude: -79.368333
# Number of Bikes: 2
# -----------------------------
# Station Name: Chatham Ave / Byron Ave
# Latitude: 43.6798678328407
# Longitude: -79.33424613862303
# Number of Bikes: 4
# -----------------------------
# Station Name: Wakunda Pl / O'Connor Dr
# Latitude: 43.71602024377182
# Longitude: -79.3047092517501
# Number of Bikes: 3
# -----------------------------
# Station Name: Tiago Ave / Westview Blvd
# Latitude: 43.71101621552703
# Longitude: -79.30675743891624
# Number of Bikes: 10
# -----------------------------
# Station Name: Plaxton Dr / St Clair Ave E
# Latitude: 43.70751755961952
# Longitude: -79.30252066313936
# Number of Bikes: 5
# -----------------------------
# Station Name: Victoria Park Ave / Edge Park Ave
# Latitude: 43.717678679534906
# Longitude: -79.29961580314475
# Number of Bikes: 7
# -----------------------------
# Station Name: Galbraith Rd / King's College Rd
# Latitude: 43.6603874468082
# Longitude: -79.39537831814152
# Number of Bikes: 8
# -----------------------------
# Station Name: Exhibition GO Station
# Latitude: 43.6352007
# Longitude: -79.4187711
# Number of Bikes: 10
# -----------------------------
# Station Name: Princes' Blvd / Nunavut Rd
# Latitude: 43.6333523484014
# Longitude: -79.41436313073005
# Number of Bikes: 19
# -----------------------------
# Station Name: Finch Subway Station
# Latitude: 43.781877158752955
# Longitude: -79.41528502874928
# Number of Bikes: 15
# -----------------------------
# Station Name: Glencairn Subway Station
# Latitude: 43.70925763810859
# Longitude: -79.44169105036657
# Number of Bikes: 4
# -----------------------------
# Station Name: Glen Long Community Centre
# Latitude: 43.70820992643782
# Longitude: -79.45627808717194
# Number of Bikes: 7
# -----------------------------
# Station Name: Caledonia Rd / Lotherton Pathway
# Latitude: 43.70756436685646
# Longitude: -79.46571474966814
# Number of Bikes: 15
# -----------------------------
# Station Name: Harvie Ave / Rogers Rd
# Latitude: 43.68402031135697
# Longitude: -79.45297885330353
# Number of Bikes: 3
# -----------------------------
# Station Name: Ling Rd / Morningside Ave
# Latitude: 43.766663817888656
# Longitude: -79.18521765344238
# Number of Bikes: 14
# -----------------------------
# Station Name: Lake Shore Blvd W / Legion Rd
# Latitude: 43.62052630763223
# Longitude: -79.48320224237995
# Number of Bikes: 15
# -----------------------------
# Station Name: Lake Shore Blvd W / Seventeenth St
# Latitude: 43.59841926031898
# Longitude: -79.51561102394257
# Number of Bikes: 7
# -----------------------------
# Station Name: Mabelle Park
# Latitude: 43.645389479325615
# Longitude: -79.5276822170925
# Number of Bikes: 7
# -----------------------------
# Station Name: Islington Subway Station (Aberfoyle Cres)
# Latitude: 43.645658591546216
# Longitude: -79.52339938954925
# Number of Bikes: 9
# -----------------------------
# Station Name: Lake Shore Blvd W / Long Branch Ave
# Latitude: 43.59445833196281
# Longitude: -79.53387390859834
# Number of Bikes: 9
# -----------------------------
# Station Name: Second St / Lake Shore Blvd W
# Latitude: 43.60191488118503
# Longitude: -79.49941888654288
# Number of Bikes: 11
# -----------------------------
# Station Name: Bloor St W / Dundas St W (2)
# Latitude: 43.64285244644315
# Longitude: -79.53199489206543
# Number of Bikes: 1
# -----------------------------
# Station Name: Temperance St Station
# Latitude: 43.650945
# Longitude: -79.379498
# Number of Bikes: 18
# -----------------------------
# Station Name: Viewmount Park
# Latitude: 43.70735572654095
# Longitude: -79.43723072209013
# Number of Bikes: 3
# -----------------------------
# Station Name: Sixth St / Lake Shore Blvd W
# Latitude: 43.60116229109828
# Longitude: -79.50416046627045
# Number of Bikes: 6
# -----------------------------
# Station Name: Queen St W / John St
# Latitude: 43.650077
# Longitude: -79.391291
# Number of Bikes: 17
# -----------------------------
# Station Name: Maud St / Adelaide St W
# Latitude: 43.6460145694434
# Longitude: -79.39960497726345
# Number of Bikes: 10
# -----------------------------
# Station Name: York Recreation Centre
# Latitude: 43.688153079245126
# Longitude: -79.48219789940566
# Number of Bikes: 8
# -----------------------------
# Station Name: Trethewey Dr / Black Creek Dr
# Latitude: 43.695498400279796
# Longitude: -79.48809394482672
# Number of Bikes: 6
# -----------------------------
# Station Name: Keele St / Ingram Dr
# Latitude: 43.698706949666914
# Longitude: -79.4756586460327
# Number of Bikes: 3
# -----------------------------
# Station Name: Jane St / Haney Ave
# Latitude: 43.6743457123134
# Longitude: -79.4948437786083
# Number of Bikes: 11
# -----------------------------
# Station Name: Scarlett Rd / Eileen Ave
# Latitude: 43.668510906505354
# Longitude: -79.5007648392868
# Number of Bikes: 2
# -----------------------------
# Station Name: Scarlett Rd / Old Scarlett Rd
# Latitude: 43.678276306636576
# Longitude: -79.50667332401198
# Number of Bikes: 9
# -----------------------------
# Station Name: Eglinton Ave W / Venn Cres
# Latitude: 43.69143920681119
# Longitude: -79.46908634795456
# Number of Bikes: 6
# -----------------------------
# Station Name: Rogers Rd / Bicknell Ave
# Latitude: 43.68189526215492
# Longitude: -79.4736382392868
# Number of Bikes: 3
# -----------------------------
# Station Name: Cruickshank Park
# Latitude: 43.7023860650084
# Longitude: -79.52594758324148
# Number of Bikes: 3
# -----------------------------
# Station Name: Mallaby Park
# Latitude: 43.706191092397106
# Longitude: -79.53262795581969
# Number of Bikes: 4
# -----------------------------
# Station Name: Emmett Ave
# Latitude: 43.68735514096443
# Longitude: -79.50623313806341
# Number of Bikes: 11
# -----------------------------
# Station Name: Jane St / Weston Rd
# Latitude: 43.69144464414302
# Longitude: -79.50154583869246
# Number of Bikes: 11
# -----------------------------
# Station Name: Jane St / Queens Dr
# Latitude: 43.70673804962302
# Longitude: -79.50477543802873
# Number of Bikes: 1
# -----------------------------
# Station Name: 2700 Eglinton Ave W
# Latitude: 43.69074600637147
# Longitude: -79.47820143344333
# Number of Bikes: 37
# -----------------------------
# Station Name: 265 Armadale Ave
# Latitude: 43.6501644
# Longitude: -79.48296909999999
# Number of Bikes: 19
# -----------------------------
# Station Name: Sentinel Rd / Sheppard Ave W
# Latitude: 43.74386580997666
# Longitude: -79.49181654358595
# Number of Bikes: 13
# -----------------------------
# Station Name: High Park - West Rd
# Latitude: 43.651922
# Longitude: -79.465693
# Number of Bikes: 1
# -----------------------------
# Station Name: High Park Amphitheatre
# Latitude: 43.646251
# Longitude: -79.46472
# Number of Bikes: 6
# -----------------------------
# Station Name: High Park Outdoor Pool
# Latitude: 43.650154
# Longitude: -79.464934
# Number of Bikes: 16
# -----------------------------
# Station Name: Humber River Hospital
# Latitude: 43.72537884183677
# Longitude: -79.48719674218903
# Number of Bikes: 8
# -----------------------------
# Station Name: Sheppard Ave W / Chesswood Dr
# Latitude: 43.755583971122874
# Longitude: -79.47446032684479
# Number of Bikes: 4
# -----------------------------
# Station Name: Jane St / Lawrence Ave W
# Latitude: 43.702340220597975
# Longitude: -79.50347389514123
# Number of Bikes: 5
# -----------------------------
# Station Name: Sussex Ave / St George St
# Latitude: 43.665304278965365
# Longitude: -79.39938263802871
# Number of Bikes: 3
# -----------------------------
# Station Name: Keele St / Catford Rd
# Latitude: 43.75919330632997
# Longitude: -79.49001046850891
# Number of Bikes: 11
# -----------------------------
# Station Name: Queens Quay E / Merchants' Wharf
# Latitude: 43.64643026333144
# Longitude: -79.3618163165329
# Number of Bikes: 6
# -----------------------------
# Station Name: Gerrard St E / Nasmith Ave
# Latitude: 43.66273618779861
# Longitude: -79.36253100740966
# Number of Bikes: 3
# -----------------------------
# Station Name: King St W / Portland St
# Latitude: 43.644395
# Longitude: -79.40065430000001
# Number of Bikes: 16
# -----------------------------
# Station Name: Sentinel Rd / Finch Ave W
# Latitude: 43.76073963892478
# Longitude: -79.5000273116394
# Number of Bikes: 6
# -----------------------------
# Station Name: Oakdale Community Centre
# Latitude: 43.74751496038769
# Longitude: -79.5132569853195
# Number of Bikes: 8
# -----------------------------
# Station Name: The Pond Rd / Ian Macdonald Blvd
# Latitude: 43.77086729028769
# Longitude: -79.49812990660705
# Number of Bikes: 10
# -----------------------------
# Station Name: 75 Holly St
# Latitude: 43.7063279
# Longitude: -79.3962499
# Number of Bikes: 5
# -----------------------------
# Station Name: Bathurst St / Dundas St W
# Latitude: 43.6518918789007
# Longitude: -79.40577861712723
# Number of Bikes: 0
# -----------------------------
# Station Name: 695 Lansdowne Ave
# Latitude: 43.659221843735615
# Longitude: -79.44277410244676
# Number of Bikes: 1
# -----------------------------
# Station Name: Jane St / Yewtree Blvd
# Latitude: 43.75531728502427
# Longitude: -79.51704708227844
# Number of Bikes: 4
# -----------------------------
# Station Name: Weston Rd / Sheppard Ave W
# Latitude: 43.73262849415089
# Longitude: -79.5381993243286
# Number of Bikes: 6
# -----------------------------
# Station Name: Jane St / Yorkwoods Gt
# Latitude: 43.7503016975738
# Longitude: -79.51577557434386
# Number of Bikes: 6
# -----------------------------
# Station Name: Weston Rd / Lanyard Rd
# Latitude: 43.74931920634839
# Longitude: -79.5419939152054
# Number of Bikes: 4
# -----------------------------
# Station Name: Lindylou Rd / Lanyard Rd
# Latitude: 43.74845421407306
# Longitude: -79.5504039969242
# Number of Bikes: 7
# -----------------------------
# Station Name: Tangiers Rd / Finch Ave W
# Latitude: 43.76376964130183
# Longitude: -79.48809242593383
# Number of Bikes: 5
# -----------------------------
# Station Name: Queen's Park Cres E / Grosvenor St - SMART
# Latitude: 43.661803
# Longitude: -79.389682
# Number of Bikes: 4
# -----------------------------
# Station Name: Wynford Heights Cres / Concorde Pl
# Latitude: 43.72749778259739
# Longitude: -79.32714222209015
# Number of Bikes: 3
# -----------------------------
# Station Name: Bartley Park
# Latitude: 43.72211166436462
# Longitude: -79.30864830919265
# Number of Bikes: 8
# -----------------------------
# Station Name: Brooklawn Ave / Kingston Rd
# Latitude: 43.721761400691236
# Longitude: -79.2359137196434
# Number of Bikes: 0
# -----------------------------
# Station Name: Gerrard Square Mall (1010 Gerrard St E)
# Latitude: 43.668553
# Longitude: -79.338673
# Number of Bikes: 7
# -----------------------------
# Station Name: John St  / Mercer St - SMART
# Latitude: 43.6461
# Longitude: -79.3895
# Number of Bikes: 0
# -----------------------------
# Station Name: University Ave / Gerrard St W (2)
# Latitude: 43.65748153286412
# Longitude: -79.38921396018827
# Number of Bikes: 16
# -----------------------------
# Station Name: Queens Park Cres / College St
# Latitude: 43.66018127636866
# Longitude: -79.39083271520538
# Number of Bikes: 1
# -----------------------------
# Station Name: 15 Price St
# Latitude: 43.6799477790745
# Longitude: -79.38994813684005
# Number of Bikes: 1
# -----------------------------
# Station Name: Jane St / Finch Ave W
# Latitude: 43.759292283169536
# Longitude: -79.5183741465576
# Number of Bikes: 0
# -----------------------------
# Station Name: 800 Fleet St (South)
# Latitude: 43.636804
# Longitude: -79.408832
# Number of Bikes: 16
# -----------------------------
# Station Name: 800 Fleet St (North)
# Latitude: 43.63679167890664
# Longitude: -79.40883087483405
# Number of Bikes: 19
# -----------------------------
# Station Name: Uno Dr / The Queensway
# Latitude: 43.62649329992186
# Longitude: -79.50358167641535
# Number of Bikes: 4
# -----------------------------
# Station Name: Simcoe St / Elm St
# Latitude: 43.656038841714505
# Longitude: -79.38970387738495
# Number of Bikes: 0
# -----------------------------

# %%
#Parse the JSON object into a Pandas dataframe.


import requests
import pandas as pd

# Send GET request to the API
response = requests.get("http://api.citybik.es/v2/networks?fields=id,name,href")

# Raise an exception if the request was unsuccessful
response.raise_for_status()

# Parse JSON response
data = response.json()

# Convert data to DataFrame
df = pd.json_normalize(data['networks'])

print(df)
# Out:
#                                  href                   id  \
# 0        /v2/networks/velobike-moscow      velobike-moscow
# 1        /v2/networks/baerum-bysykkel      baerum-bysykkel
# 2       /v2/networks/bicincitta-siena     bicincitta-siena
# 3    /v2/networks/cyclopolis-maroussi  cyclopolis-maroussi
# 4     /v2/networks/cyclopolis-nafplio   cyclopolis-nafplio
# ..                                ...                  ...
# 673     /v2/networks/enlabici-mendoza     enlabici-mendoza
# 674           /v2/networks/passofundo           passofundo
# 675             /v2/networks/cascavel             cascavel
# 676            /v2/networks/yelo-velo            yelo-velo
# 677         /v2/networks/ganxeta-reus         ganxeta-reus
#
#                         name
# 0                   Velobike
# 1                   Bysykkel
# 2                 Bicincittà
# 3                 Cyclopolis
# 4                 Cyclopolis
# ..                       ...
# 673               En la Bici
# 674  Passo Fundo Vai de Bici
# 675     Cascavel Vai de Bici
# 676                Yélo Vélo
# 677                  Ganxeta
#
# [678 rows x 3 columns]

# %%
# !pwd
# Out:
# /Users/hm4th

# %%
#Explore the structure of the API, query the API and understand the data returned.

'''
Choose a city covered by the CityBikes API and retrieve all available bike stations in that city:

To choose a city, you can provide the city name as an input to the get_bike_stations(city) function.
The function constructs the API URL using the provided city name and the desired fields (id, name, href).
It sends a GET request to the constructed URL using the requests library.
If the request is successful (status code 200), it retrieves the JSON response and extracts the list of
bike stations from the network field.
The function returns the list of bike stations.
For each bike station, use the API to call the latitude, longitude, and number of bikes:

The code snippet within the get_bike_stations(city) function iterates over each bike station in the retrieved list.
It accesses the station details such as name, latitude, longitude, and the number of available bikes using the 
get() method on the station dictionary.
It prints the station details for each bike station.
Parse the JSON object into a Pandas dataframe:

The code snippet demonstrates an alternative approach to parsing the JSON response using the pandas library.
It sends a GET request to the API URL without specifying a city.
If the request is successful, it retrieves the JSON response and normalizes it into a DataFrame using 
pd.json_normalize().
The resulting DataFrame (df) contains information about multiple bike-sharing networks, including their IDs, 
names, and URLs.

'''
